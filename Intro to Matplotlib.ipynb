# %% [markdown]
# ## Intro to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)
plt.show()

# %%
# 1st method
fig=plt.figure() #creates a figure
ax=fig.add_subplot() #adds an axes
plt.show()

# %%
#2nd method
fig=plt.figure() #creates a figure
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig,ax=plt.subplots()
ax.plot(x,[50,100,200,250]) #add some data
print(type(fig),type(ax))
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'> <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# ## Matplotlib example workflow

# %%
#0. Import matplotlib and git it ready for plotting
# %matplotlib inline
import matplotlib.pyplot as plt

#1.Prepare data
x=[1,2,3,4]
y=[11,22,33,44]

#2. Setup plot
fig,ax=plt.subplots(figsize=(5,10))  #(width,height)

#3. Plot data
ax.plot(x,y)

#4. customize plot
ax.set(title="simple plot",
       xlabel="x-axis",
       ylabel="y-axis")
plt.show()
#5. Save and show (you have the whole figure)
# fig.savefig("OneDrive/Desktop/sample_project_1/numpy-images/sampleplot.png")

# %% [markdown]
# ## Making figures with numpy array
#
# We want:
# *Line plot
# *Scater plot
# *Bar plot
# *Histogram
# *Subplots

# %%
import numpy as np

# %%
#Create some data
x=np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
#plot the data and create a line plot
fig,ax=plt.subplots()
ax.plot(x,x**2)
plt.show()

# %%
# use the same data to create scatter plot
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))
plt.show()

# %%
#another scatter plot
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))
plt.show()

# %%
#Make a plot from dictionary
nut_butter={"Almond butter":10,
            "Peanut butter":8,
            "Cashew butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter.keys(),nut_butter.values())
ax.set(title="Nut butter Store",
       ylabel="Price ($)")

plt.show()

# %%
fig,ax=plt.subplots()
ax.barh(list(nut_butter.keys()),list(nut_butter.values()))
plt.show()

# %%
# Make some data for histograms and plot it
x=np.random.randn(1000)
fig,ax=plt.subplots()
ax.hist(x)
plt.show()

# %% [markdown]
# ### Two options for subplots

# %%
#Subplots option 1
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,
                                       ncols=2,
                                       figsize=(10,5))


#Plot to each axis
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter.keys(),nut_butter.values())
ax4.hist(np.random.randn(1000))
plt.show()

# %%
#Subplots option 2
fig,ax=plt.subplots(nrows=2,
                    ncols=2,
                    figsize=(10,5))

#Plot to each diff. index
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter.keys(),nut_butter.values())
ax[1,1].hist(np.random.randn(1000))
plt.show()

# %% [markdown]
# ## Plotting from pandas dagtaframes

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales=pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts=pd.Series(np.random.randn(1000),
             index=pd.date_range("1/1/2025",periods=1000))
ts.cumsum()
ts.plot()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"]=car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"]=pd.date_range("1/1/2025",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2025-01-01
# 1   Honda    Red          87899      4   5000 2025-01-02
# 2  Toyota   Blue          32549      3   7000 2025-01-03
# 3     BMW  Black          11179      5  22000 2025-01-04
# 4  Nissan  White         213095      4   3500 2025-01-05
# 5  Toyota  Green          99213      4   4500 2025-01-06
# 6   Honda   Blue          45698      4   7500 2025-01-07
# 7   Honda   Blue          54738      4   7000 2025-01-08
# 8  Toyota  White          60000      4   6250 2025-01-09
# 9  Nissan  White          31600      4   9700 2025-01-10

# %%
car_sales["Total sales"]=car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
# Let's plot total sales
car_sales.plot(x="Sale Date",y="Total sales")
plt.show()

# %%
car_sales["Price"]=car_sales["Price"].astype(int)
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
plt.show()

# %%
# How about a bar graph?
x=np.random.rand(10,4)
x

#Trun it into dataframe
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.106272  0.141426  0.184736  0.830621
# 1  0.394502  0.378053  0.535604  0.615293
# 2  0.506804  0.380532  0.822341  0.997209
# 3  0.104249  0.745335  0.723563  0.114218
# 4  0.931341  0.034092  0.151896  0.757148
# 5  0.902851  0.650648  0.206285  0.578762
# 6  0.532666  0.363354  0.715845  0.813351
# 7  0.361956  0.792732  0.362994  0.048106
# 8  0.552183  0.490726  0.817980  0.456272
# 9  0.216759  0.479195  0.315381  0.457726

# %%
df.plot.bar()
plt.show()

# %%
df.plot(kind="bar")
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500
# 5  Toyota  Green          99213      4   4500 2025-01-06        46000
# 6   Honda   Blue          45698      4   7500 2025-01-07        53500
# 7   Honda   Blue          54738      4   7000 2025-01-08        60500
# 8  Toyota  White          60000      4   6250 2025-01-09        66750
# 9  Nissan  White          31600      4   9700 2025-01-10        76450

# %%
car_sales.plot(x="Make",y="Odometer (KM)",kind="bar")
plt.show()

# %%
# Histogram

car_sales["Odometer (KM)"].plot.hist()
plt.show()

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
plt.show()

# %%
car_sales["Price"].plot.hist(bins=30)
plt.show()

# %%
# let's try on another dataset
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create histogram for age
heart_disease["age"].plot.hist()
plt.show()

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True)
plt.show()

# %% [markdown]
# ### Which one should you use? (Pyplot vs matplotlib OO Method?)
#
# *when plotting something quickly, okay to use pyplot method
# *but when plotting something more advanced, use the OO method

# %%
over_50=heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#pyplot method
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
            figsize=(10,6))
plt.show()

# %%
#OO method
fix,ax=plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
             x="age",
             y="chol",
             c="target",
             ax=ax)
# ax.set_xlim([45,100])
plt.show()

# %%
## OO method from scratch
fig,ax=plt.subplots(figsize=(10,6))

#Plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"])

#Customizze
ax.set(title="Heart disease and cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

#Add a legend
ax.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal
ax.axhline(over_50["chol"].mean(),
          linestyle='--')
plt.show()

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
#subplot of age,chol and talach
fig, (ax0,ax1)=plt.subplots(nrows=2,
                            ncols=1,
                            figsize=(10,10),
                            sharex=True)

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

#Customize ax0
ax0.set(title="Heart disease and cholesterol levels",
        ylabel="Cholesterol")

#add alegend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
#add mean line
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

#Add data to ax1
scatter=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])

#Customize ax1
ax1.set(title="Heart disease and max heart rate",
        xlabel="Age",
        ylabel="Max heart rate")
#Add legend
ax1.legend(*scatter.legend_elements(),title="Target")
#Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle='--')

#add atitle to the figure
fig.suptitle("Heart disease analysis",fontsize=16,fontweight="bold")
plt.show()

# %% [markdown]
# ## Customizing Matplotlib plots and getting it stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot()
plt.show()

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total sales
# 0  Toyota  White         150043      4   4000 2025-01-01         4000
# 1   Honda    Red          87899      4   5000 2025-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2025-01-03        16000
# 3     BMW  Black          11179      5  22000 2025-01-04        38000
# 4  Nissan  White         213095      4   3500 2025-01-05        41500

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
car_sales["Price"].plot()
plt.show()

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot()
plt.show()

# %%
car_sales.plot(x="Odometer (KM)",y="Price",kind="scatter")
plt.show()

# %%
plt.style.use("ggplot")

# %%
car_sales["Price"].plot()
plt.show()

# %%
# create some data
x=np.random.randn(10,4)
x
# Out:
# array([[ 0.30230106,  0.99127214,  1.09933202,  1.29274681],
#        [-1.42588017, -0.08520676,  0.18379801, -0.08521914],
#        [ 0.33845951,  0.56780037,  0.2187328 , -0.88432296],
#        [-0.34337716,  0.53596451,  1.07807317, -0.67671291],
#        [ 2.90681402, -0.65612487,  0.70399158,  0.11371211],
#        [-0.42745025, -0.36418347,  1.1522883 , -0.15883384],
#        [-0.77072616,  1.44579803, -0.79990693,  0.72931719],
#        [-1.12920669, -0.22922547,  0.81857294,  0.27022651],
#        [-0.31490406,  0.69592977, -0.45853333, -0.9982184 ],
#        [-0.26334227, -1.48901424, -0.06231482, -1.01355364]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.302301  0.991272  1.099332  1.292747
# 1 -1.425880 -0.085207  0.183798 -0.085219
# 2  0.338460  0.567800  0.218733 -0.884323
# 3 -0.343377  0.535965  1.078073 -0.676713
# 4  2.906814 -0.656125  0.703992  0.113712
# 5 -0.427450 -0.364183  1.152288 -0.158834
# 6 -0.770726  1.445798 -0.799907  0.729317
# 7 -1.129207 -0.229225  0.818573  0.270227
# 8 -0.314904  0.695930 -0.458533 -0.998218
# 9 -0.263342 -1.489014 -0.062315 -1.013554

# %%
ax=df.plot(kind="bar")
type(ax)
plt.show()

# %%
# customize the plot with set() method
ax=df.plot(kind="bar")
#add labels and title
ax.set(title="Random number bar gragh",
       xlabel="Row number",
       ylabel="Random number")
#make legend visible
ax.legend().set_visible(True)
plt.show()

# %%
#Set the style
plt.style.use("seaborn-v0_8-whitegrid")

## OO method from scratch
fig,ax=plt.subplots(figsize=(10,6))

#Plot the data
scatter=ax.scatter(x=over_50["age"],
                   y=over_50["chol"],
                   c=over_50["target"],
                   cmap="summer")

#Customizze
ax.set(title="Heart disease and cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol")

#Add a legend
ax.legend(*scatter.legend_elements(),title="Target")

#Add a horizontal
ax.axhline(over_50["chol"].mean(),
          linestyle='--')
plt.show()

# %%
#subplot of age,chol and talach
fig, (ax0,ax1)=plt.subplots(nrows=2,
                            ncols=1,
                            figsize=(10,10),
                            sharex=True)

#add data to ax0
scatter=ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="summer")

#Customize ax0
ax0.set(title="Heart disease and cholesterol levels",
        ylabel="Cholesterol")

#change x axis limits
ax0.set_xlim([50,80])

#add alegend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")
#add mean line
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--")

#Add data to ax1
scatter=ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter")

#Customize ax1
ax1.set(title="Heart disease and max heart rate",
        xlabel="Age",
        ylabel="Max heart rate")

#change limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
#Add legend
ax1.legend(*scatter.legend_elements(),title="Target")
#Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle='--')

#add atitle to the figure
fig.suptitle("Heart disease analysis",fontsize=16,fontweight="bold")
plt.show()

# %%
fig

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
